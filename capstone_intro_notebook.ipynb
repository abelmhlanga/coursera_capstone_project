# %% [markdown]
# <h1>capstone Project Intro</h1>

# %%
a = 1 + 5
print("The sum is :", a)
# Out:
# The sum is : 6

# %%
b = 2 + 5

# %%
print("Sum :", b)
# Out:
# Sum : 7

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
